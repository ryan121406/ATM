# %% [markdown]
# <a href="https://colab.research.google.com/github/ryan121406/ATM/blob/main/P_107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f3e972b-48e7-40c9-9530-c8b438e6a321" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f3e972b-48e7-40c9-9530-c8b438e6a321">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.txt to data.txt

# %%
import pandas as pd 
df = pd.read_csv("data.txt")
df
# Out:
#      student_id    level  attempt
# 0       TRL_xsl  Level 4        1
# 1       TRL_xsl  Level 1        1
# 2       TRL_xsl  Level 2        1
# 3       TRL_xsl  Level 3        1
# 4       TRL_xsl  Level 4        1
# ...         ...      ...      ...
# 1650    TRL_zny  Level 3        1
# 1651    TRL_zny  Level 3        0
# 1652    TRL_zny  Level 3        1
# 1653    TRL_zny  Level 4        1
# 1654    TRL_zny  Level 3        0
#
# [1655 rows x 3 columns]

# %%
import plotly.express as px

# %%
df1 = df.groupby(['student_id','level'],as_index = False).mean()
df1
# Out:
#    student_id    level   attempt
# 0     TRL_123  Level 1  0.937500
# 1     TRL_123  Level 4  1.000000
# 2     TRL_987  Level 1  1.000000
# 3     TRL_987  Level 2  0.937500
# 4     TRL_987  Level 3  0.695652
# 5     TRL_987  Level 4  0.740741
# 6     TRL_abc  Level 1  0.888889
# 7     TRL_abc  Level 2  0.833333
# 8     TRL_abc  Level 3  0.700000
# 9     TRL_abc  Level 4  0.647059
# 10    TRL_imb  Level 1  0.735294
# 11    TRL_imb  Level 2  0.784314
# 12    TRL_imb  Level 3  0.833333
# 13    TRL_imb  Level 4  0.558824
# 14    TRL_mda  Level 1  0.677419
# 15    TRL_mda  Level 2  0.909091
# 16    TRL_mda  Level 3  0.655172
# 17    TRL_mda  Level 4  0.782730
# 18    TRL_mno  Level 1  0.680000
# 19    TRL_mno  Level 2  0.937500
# 20    TRL_mno  Level 3  0.833333
# 21    TRL_mno  Level 4  0.833333
# 22    TRL_rst  Level 1  0.622222
# 23    TRL_rst  Level 2  0.789474
# 24    TRL_rst  Level 3  0.789474
# 25    TRL_rst  Level 4  0.700000
# 26    TRL_xsl  Level 1  1.000000
# ...

# %%
fig = px.scatter(df1, x ='student_id', y = 'level',color = 'attempt', size = 'attempt', size_max = 40)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="65b36582-a4ff-4171-9b77-28a72877fac2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65b36582-a4ff-4171-9b77-28a72877fac2")) {
#                     Plotly.newPlot(
#                         '65b36582-a4ff-4171-9b77-28a72877fac2',
# ...
